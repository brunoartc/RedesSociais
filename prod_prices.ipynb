# %%
import pandas as pd

# %%
data = pd.read_csv('DatafinitiElectronicsProductsPricingData.csv')
data
# Out:
#                          id  prices.amountMax  prices.amountMin  \
# 0      AVphzgbJLJeJML43fA0o            104.99            104.99
# 1      AVpgMuGwLJeJML43KY_c             69.00             64.99
# 2      AVpgMuGwLJeJML43KY_c             69.00             69.00
# 3      AVpgMuGwLJeJML43KY_c             69.99             69.99
# 4      AVpgMuGwLJeJML43KY_c             66.99             66.99
# ...                     ...               ...               ...
# 14587  AVpgibRDLJeJML43PTZX             65.99             65.99
# 14588  AVpgibRDLJeJML43PTZX             58.99             58.99
# 14589  AVpgibRDLJeJML43PTZX             58.49             58.49
# 14590  AVpgibRDLJeJML43PTZX             77.98             77.98
# 14591  AVpgibRDLJeJML43PTZX             71.95             71.95
#
#       prices.availability prices.condition prices.currency  \
# 0                     Yes              New             USD
# 1                In Stock              New             USD
# ...

# %%
data.loc[data['prices.amountMin'] > 19000]
# Out:
#                          id  prices.amountMax  prices.amountMin  \
# 10483  AVph8rYRilAPnD_x_GYE          26871.00          26871.00
# 11325  AV2ZqC3JglJLPUi8QkKo          19997.99          19997.99
# 11326  AV2ZqC3JglJLPUi8QkKo          19997.99          19997.99
# 11327  AV2ZqC3JglJLPUi8QkKo          19997.99          19997.99
# 11328  AV2ZqC3JglJLPUi8QkKo          19997.99          19997.99
# 11329  AV2ZqC3JglJLPUi8QkKo          19999.99          19999.99
# 11330  AV2ZqC3JglJLPUi8QkKo          19997.99          19997.99
# 11331  AV2ZqC3JglJLPUi8QkKo          19999.99          19999.99
# 11332  AV2ZqC3JglJLPUi8QkKo          19997.99          19997.99
#
#       prices.availability prices.condition prices.currency  \
# 10483                 NaN              New             USD
# 11325                 NaN              NaN             USD
# 11326                 NaN              NaN             USD
# 11327                 NaN              NaN             USD
# ...
